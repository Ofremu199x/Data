# %% [markdown]
# # Bank Data

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/bank-full.csv')

# %%
data.tail(20)
# Out:
#        age            job   marital  education default  balance housing loan  \
# 45191   75        retired  divorced   tertiary      no     3810     yes   no
# 45192   29     management    single   tertiary      no      765      no   no
# 45193   28  self-employed    single   tertiary      no      159      no   no
# 45194   59     management   married   tertiary      no      138     yes  yes
# 45195   68        retired   married  secondary      no     1146      no   no
# 45196   25        student    single  secondary      no      358      no   no
# 45197   36     management    single  secondary      no     1511     yes   no
# 45198   37     management   married   tertiary      no     1428      no   no
# 45199   34    blue-collar    single  secondary      no     1475     yes   no
# 45200   38     technician   married  secondary      no      557     yes   no
# 45201   53     management   married   tertiary      no      583      no   no
# ...

# %%
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  previous
# 0  unknown    5   may       261         0
# 1  unknown    5   may       151         0
# 2  unknown    5   may        76         0
# 3  unknown    5   may        92         0
# 4  unknown    5   may       198         0

# %%
# @title balance

from matplotlib import pyplot as plt
data['balance'].plot(kind='hist', bins=20, title='balance')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title age

from matplotlib import pyplot as plt
data['age'].plot(kind='hist', bins=20, title='age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data_marital = data.groupby(['marital'])

data_marital.describe()
# Out:
#               age                                                      \
#             count       mean        std   min   25%   50%   75%   max
# marital
# divorced   5207.0  45.782984  10.124719  24.0  38.0  45.0  53.0  95.0
# married   27214.0  43.408099  10.264452  20.0  35.0  42.0  51.0  95.0
# single    12790.0  33.703440   7.603166  18.0  29.0  32.0  37.0  86.0
#
#           balance               ... duration         previous            \
#             count         mean  ...      75%     max    count      mean
# marital                         ...
# divorced   5207.0  1178.872287  ...    322.0  3094.0   5207.0  0.551373
# married   27214.0  1425.925590  ...    312.0  4918.0  27214.0  0.556552
# single    12790.0  1301.497654  ...    332.0  3785.0  12790.0  0.642690
#
#
#                std  min  25%  50%  75%    max
# marital
# divorced  1.811625  0.0  0.0  0.0  0.0   30.0
# married   2.478797  0.0  0.0  0.0  0.0  275.0
# single    2.083432  0.0  0.0  0.0  0.0   51.0
#
# ...

# %%
data[['marital','education','housing']]
# Out:
#         marital  education housing
# 0       married   tertiary     yes
# 1        single  secondary     yes
# 2       married  secondary     yes
# 3       married    unknown     yes
# 4        single    unknown      no
# ...         ...        ...     ...
# 45206   married   tertiary      no
# 45207  divorced    primary      no
# 45208   married  secondary      no
# 45209   married  secondary      no
# 45210   married  secondary      no
#
# [45211 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('marital').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_2.groupby('housing').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_1.groupby('education').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_0.groupby('marital').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#Let get all the people who have a loan with our bank for the month of may and see the frequency by day

debitors = data [data['loan'] =='yes']

debt_month = debitors[debitors['month'] == 'may']

debt_month
# Out:
#        age           job   marital  education default  balance housing loan  \
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 6       28    management    single   tertiary      no      447     yes  yes
# 20      28   blue-collar   married  secondary      no      723     yes  yes
# 22      32   blue-collar    single    primary      no       23     yes  yes
# 24      40       retired   married    primary      no        0     yes  yes
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 43724   35    technician   married  secondary      no       18     yes  yes
# 43727   48    technician  divorced  secondary      no      -63      no  yes
# 43730   56   blue-collar   married  secondary      no      448     yes  yes
# 43809   26    management    single   tertiary      no      531      no  yes
# 43810   26  entrepreneur    single  secondary      no      681      no  yes
#
#         contact  day month  duration  previous
# ...

# %%
# @title day

from matplotlib import pyplot as plt
debt_month['day'].plot(kind='hist', bins=20, title='day')
plt.gca().spines[['top', 'right',]].set_visible(False)
